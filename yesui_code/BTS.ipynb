# %%
# take in the downloaded csv data over a 10-year period and merge it into one database
# export the database to a CSV for the rest of the group to download 
db15 = pd.read_csv('OnewayT_T100D_SEGMENT_ALL_CARRIER2015.csv')
db16 = pd.read_csv('OnewayT_T100D_SEGMENT_ALL_CARRIER2016.csv')
db17 = pd.read_csv('OnewayT_T100D_SEGMENT_ALL_CARRIER2017.csv')
db18 = pd.read_csv('OnewayT_T100D_SEGMENT_ALL_CARRIER2018.csv')
db19 = pd.read_csv('OnewayT_T100D_SEGMENT_ALL_CARRIER2019.csv')
db20 = pd.read_csv('OnewayT_T100D_SEGMENT_ALL_CARRIER2020.csv')
db21 = pd.read_csv('OnewayT_T100D_SEGMENT_ALL_CARRIER2021.csv')
db22 = pd.read_csv('OnewayT_T100D_SEGMENT_ALL_CARRIER2022.csv')
db23 = pd.read_csv('OnewayT_T100D_SEGMENT_ALL_CARRIER2023.csv')
db24 = pd.read_csv('OnewayT_T100D_SEGMENT_ALL_CARRIER2024.csv')
db25 = pd.read_csv('OnewayT_T100D_SEGMENT_ALL_CARRIER2025.csv')
# concatenating the data over each year into one dataframe 
frames = [db15, db16, db17, db18, db19, db20, db21, db22, db23, db24, db25]
mergedResults = pd.concat(frames)
groupedResults = mergedResults.groupby('UNIQUE_CARRIER')['Sum(DEPARTURES_PERFORMED)'].sum().reset_index()
# merging the results into a CSV 
mergedResults.to_csv('Merged10yrOperatordata2.csv', index=False)

# %%
df = pd.read_csv('Merged10yrOperatordata2.csv', low_memory=False)
df.head(10)
# Out:
#   UNIQUE_CARRIER                                        Description  \
# 0              -                                            Unknown
# 1            02Q                                      Titan Airways
# 2            04Q                                 Tradewind Aviation
# 3            09Q  Swift Air, LLC d/b/a Eastern Air Lines d/b/a E...
# 4            0BQ                                                DCA
# 5            0CQ                               ACM AIR CHARTER GmbH
# 6            0GQ       Inter Island Airways, d/b/a Inter Island Air
# 7            0JQ                                    Vision Airlines
# 8            0QQ                             TAG Aviation (UK) Ltd.
# 9            0RQ                           TAG Aviation Espana S.L.
#
#    Sum(DEPARTURES_PERFORMED)
# 0                        360
# 1                          1
# 2                       3597
# 3                       2809
# 4                         12
# 5                         22
# ...
